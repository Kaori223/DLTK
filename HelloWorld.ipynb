# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaori223/DLTK/blob/master/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
print(3+2)
# Out:
# Hello World
# 5

# %%
1+1
# Out:
# 2

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
pip install sklearn.datasets
# Out:
# ERROR: Could not find a version that satisfies the requirement sklearn.datasets (from versions: none)
# ERROR: No matching distribution found for sklearn.datasets

# %%
from sklearn.datasets import load_breast_cancer

# %%
breast_cancer = load_breast_cancer()
X = breast_cancer.data  # 特徴量
y = breast_cancer.target  # 目的変数
feature_names = breast_cancer.feature_names  # 特徴量名

# %%
print(feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
# Xの全ての行と10列目までを取り出す
X = X[:, :10]

# %%
columns = ['半径', 'テクスチャ', '周囲の長さ', '面積', 'なめらかさ', 'コンパクト性', 'へこみ', 'へこみの数', '対称性', 'フラクタル次元']

# %%
from pandas import DataFrame

df = DataFrame(data=X[:, :10], columns=columns)
df['目的変数'] = y

df.tail()  # 下から5行を表示する
# Out:
#         半径  テクスチャ   周囲の長さ      面積  ...    へこみの数     対称性  フラクタル次元  目的変数
# 564  21.56  22.39  142.00  1479.0  ...  0.13890  0.1726  0.05623     0
# 565  20.13  28.25  131.20  1261.0  ...  0.09791  0.1752  0.05533     0
# 566  16.60  28.08  108.30   858.1  ...  0.05302  0.1590  0.05648     0
# 567  20.60  29.33  140.10  1265.0  ...  0.15200  0.2397  0.07016     0
# 568   7.76  24.54   47.92   181.0  ...  0.00000  0.1587  0.05884     1
#
# [5 rows x 11 columns]

# %%
df.describe()
# Out:
#                半径       テクスチャ       周囲の長さ  ...         対称性     フラクタル次元        目的変数
# count  569.000000  569.000000  569.000000  ...  569.000000  569.000000  569.000000
# mean    14.127292   19.289649   91.969033  ...    0.181162    0.062798    0.627417
# std      3.524049    4.301036   24.298981  ...    0.027414    0.007060    0.483918
# min      6.981000    9.710000   43.790000  ...    0.106000    0.049960    0.000000
# 25%     11.700000   16.170000   75.170000  ...    0.161900    0.057700    0.000000
# 50%     13.370000   18.840000   86.240000  ...    0.179200    0.061540    1.000000
# 75%     15.780000   21.800000  104.100000  ...    0.195700    0.066120    1.000000
# max     28.110000   39.280000  188.500000  ...    0.304000    0.097440    1.000000
#
# [8 rows x 11 columns]

# %%
from matplotlib import pyplot
pyplot.rcParams['font.family'] = 'IPAPGothic'
from pandas.plotting import scatter_matrix

# %%
# 悪性の腫瘍を赤色、良性の腫瘍を青色にする
colors = ['red' if v == 0 else 'blue' for v in y]

# 散布図の描画
axes = scatter_matrix(df[columns], figsize=(20, 20), diagonal='kde', c=colors)
# Out:
# findfont: Font family ['IPAPGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['IPAPGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21322 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 24452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 12486 missing from current font.
# ...
